# %% [markdown]
# <a href="https://colab.research.google.com/github/koko242/NeuralNetworks-Price-notebook-Pandas/blob/main/19042021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/cake.jpg",cv2.IMREAD_COLOR)
cv2_imshow(img)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FD2889C3950>

# %%
import cv2 as cv
import glob
from google.colab.patches import cv2_imshow
#img=cv2.imread("/content/cake.jpg",cv2.IMREAD_COLOR)
#cv2_imshow(img)
path = glob.glob("/content/Cakes/*.jpg")
cv_img_test = []
for i in path:
    img = cv.imread(i)
    cv_img_test.append(img)
    #cv2_imshow(img)
print(cv_img_test)
# Out:
# [array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
